# %%
import requests
import json
import pandas as pd

# %%
response = requests.get("https://api.covid19api.com/country/pk")
data = response.json()
# pd.DataFrame.from_records(data)
df = pd.DataFrame.from_records(data)
# pd.DataFrame.from_records(data)
df.tail()
# Out:
#                                        ID   Country CountryCode Province City  \
# 769  c86b856a-b71d-4fc5-b9b5-d0ff0f294d69  Pakistan          PK
# 770  d3351e13-cc95-4651-9ae5-6411e620481c  Pakistan          PK
# 771  7be524b2-8ec2-4b08-9c6b-0cd710ce5785  Pakistan          PK
# 772  d973e14f-712f-4b33-94d3-01f396a8d0ee  Pakistan          PK
# 773  fc8708f3-ccda-407c-adc5-9d8dcf8e0b67  Pakistan          PK
#
#     CityCode    Lat    Lon  Confirmed  Deaths  Recovered   Active  \
# 769           30.38  69.35    1510986   30218          0  1480768
# 770           30.38  69.35    1511754   30237          0  1481517
# 771           30.38  69.35    1512707   30248          0  1482459
# 772           30.38  69.35    1513503   30258          0  1483245
# 773           30.38  69.35    1514258   30265          0  1483993
#
#                      Date
# 769  2022-03-01T00:00:00Z
# 770  2022-03-02T00:00:00Z
# 771  2022-03-03T00:00:00Z
# 772  2022-03-04T00:00:00Z
# 773  2022-03-05T00:00:00Z

# %%
df = pd.DataFrame.from_records(data)
df
# Out:
#                                        ID   Country CountryCode Province City  \
# 0    cabdbcc9-9bfe-42c4-9a44-68675e2eefb0  Pakistan          PK
# 1    38433e93-b7b7-400c-a6fc-2ec979b522c8  Pakistan          PK
# 2    eb4d1974-e623-4d3f-8d20-ca035875b646  Pakistan          PK
# 3    472fdfeb-8fc2-404f-a7b6-1ecb513d35ce  Pakistan          PK
# 4    02c58123-f758-491e-99dd-60988e77e951  Pakistan          PK
# ..                                    ...       ...         ...      ...  ...
# 769  c86b856a-b71d-4fc5-b9b5-d0ff0f294d69  Pakistan          PK
# 770  d3351e13-cc95-4651-9ae5-6411e620481c  Pakistan          PK
# 771  7be524b2-8ec2-4b08-9c6b-0cd710ce5785  Pakistan          PK
# 772  d973e14f-712f-4b33-94d3-01f396a8d0ee  Pakistan          PK
# 773  fc8708f3-ccda-407c-adc5-9d8dcf8e0b67  Pakistan          PK
#
#     CityCode    Lat    Lon  Confirmed  Deaths  Recovered   Active  \
# 0             30.38  69.35          0       0          0        0
# ...

# %%
dic = {"Date": "t" , "Confirmed" : "y"}
alldata  = df[["Date", "Confirmed"]]
pd.options.mode.chained_assignment = None 
alldata.rename(columns=dic,inplace=True)
max_data = alldata.groupby(alldata['t'], as_index=False).agg(int).to_dict(orient="records")
label = alldata["t"].tolist()
    
Data = {"AllData" : max_data , "labels" : label}

# %%
pd.DataFrame.from_records(data).tail()
# Out:
#                                        ID   Country CountryCode Province City  \
# 769  c86b856a-b71d-4fc5-b9b5-d0ff0f294d69  Pakistan          PK
# 770  d3351e13-cc95-4651-9ae5-6411e620481c  Pakistan          PK
# 771  7be524b2-8ec2-4b08-9c6b-0cd710ce5785  Pakistan          PK
# 772  d973e14f-712f-4b33-94d3-01f396a8d0ee  Pakistan          PK
# 773  fc8708f3-ccda-407c-adc5-9d8dcf8e0b67  Pakistan          PK
#
#     CityCode    Lat    Lon  Confirmed  Deaths  Recovered   Active  \
# 769           30.38  69.35    1510986   30218          0  1480768
# 770           30.38  69.35    1511754   30237          0  1481517
# 771           30.38  69.35    1512707   30248          0  1482459
# 772           30.38  69.35    1513503   30258          0  1483245
# 773           30.38  69.35    1514258   30265          0  1483993
#
#                      Date
# 769  2022-03-01T00:00:00Z
# 770  2022-03-02T00:00:00Z
# 771  2022-03-03T00:00:00Z
# 772  2022-03-04T00:00:00Z
# 773  2022-03-05T00:00:00Z

# %%
# df[["Date","Confirmed"]]
labels = df["Date"].tolist()
#  df.groupby(df['Date'], as_index=False).agg(int).to_dict(orient="records")
newdata = df[['Date' , 'Confirmed']]
# newdata.groupby(newdata['Date'], as_index=False).agg(int).to_dict(orient="records")
df
# Out:
#                                        ID   Country CountryCode Province City  \
# 0    cabdbcc9-9bfe-42c4-9a44-68675e2eefb0  Pakistan          PK
# 1    38433e93-b7b7-400c-a6fc-2ec979b522c8  Pakistan          PK
# 2    eb4d1974-e623-4d3f-8d20-ca035875b646  Pakistan          PK
# 3    472fdfeb-8fc2-404f-a7b6-1ecb513d35ce  Pakistan          PK
# 4    02c58123-f758-491e-99dd-60988e77e951  Pakistan          PK
# ..                                    ...       ...         ...      ...  ...
# 769  c86b856a-b71d-4fc5-b9b5-d0ff0f294d69  Pakistan          PK
# 770  d3351e13-cc95-4651-9ae5-6411e620481c  Pakistan          PK
# 771  7be524b2-8ec2-4b08-9c6b-0cd710ce5785  Pakistan          PK
# 772  d973e14f-712f-4b33-94d3-01f396a8d0ee  Pakistan          PK
# 773  fc8708f3-ccda-407c-adc5-9d8dcf8e0b67  Pakistan          PK
#
#     CityCode    Lat    Lon  Confirmed  Deaths  Recovered   Active  \
# 0             30.38  69.35          0       0          0        0
# ...

# %%
# dict = {'First Name': 'Name',
#         'Location': 'City',
#         'Pay': 'Salary'}
 
# # call rename () method
# df.rename(columns=dict,
#           inplace=True)
dic = {"Date": "t" , "Confirmed" : "y"}
alldata  = df[["Date", "Confirmed"]]
pd.options.mode.chained_assignment = None 
alldata.rename(columns=dic,inplace=True)
alldata.tail()
# Out:
#                         t        y
# 769  2022-03-01T00:00:00Z  1510986
# 770  2022-03-02T00:00:00Z  1511754
# 771  2022-03-03T00:00:00Z  1512707
# 772  2022-03-04T00:00:00Z  1513503
# 773  2022-03-05T00:00:00Z  1514258

# %%
max_data = alldata.groupby(alldata['t'], as_index=False).agg(int).to_dict(orient="records")

# %%
label = alldata["t"].tolist()
label[-10:-1]
# Out:
# ['2022-02-24T00:00:00Z',
#  '2022-02-25T00:00:00Z',
#  '2022-02-26T00:00:00Z',
#  '2022-02-27T00:00:00Z',
#  '2022-02-28T00:00:00Z',
#  '2022-03-01T00:00:00Z',
#  '2022-03-02T00:00:00Z',
#  '2022-03-03T00:00:00Z',
#  '2022-03-04T00:00:00Z']

# %%
s = pd.to_datetime(df['Date'], format='%Y%m%dT', errors='coerce')
df["Date"] = pd.to_datetime(df['Date'], format='%Y%m%dT' , utc= None).dt.normalize()
df['Date'] = pd.to_datetime(df.Date).dt.tz_localize(None)
actual_data = df[['Date','Confirmed']]
actual_data.head()
# Out:
#         Date  Confirmed
# 0 2020-01-22          0
# 1 2020-01-23          0
# 2 2020-01-24          0
# 3 2020-01-25          0
# 4 2020-01-26          0

# %%
import matplotlib.pyplot as plt

# %%
df= actual_data
df = df.sort_values('Date', ascending=True)
plt.plot(df['Date'], df['Confirmed'])
plt.xticks(rotation='vertical')
# Out:
# (array([18262., 18353., 18444., 18536., 18628., 18718., 18809., 18901.,
#         18993., 19083.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
 df.groupby(df['Date'], as_index=False).agg(int).to_dict(orient="records")[-10:-1]
    #last 10 days record
# Out:
# [{'Date': Timestamp('2022-02-24 00:00:00'), 'Confirmed': 1506450},
#  {'Date': Timestamp('2022-02-25 00:00:00'), 'Confirmed': 1507657},
#  {'Date': Timestamp('2022-02-26 00:00:00'), 'Confirmed': 1508504},
#  {'Date': Timestamp('2022-02-27 00:00:00'), 'Confirmed': 1509360},
#  {'Date': Timestamp('2022-02-28 00:00:00'), 'Confirmed': 1510221},
#  {'Date': Timestamp('2022-03-01 00:00:00'), 'Confirmed': 1510986},
#  {'Date': Timestamp('2022-03-02 00:00:00'), 'Confirmed': 1511754},
#  {'Date': Timestamp('2022-03-03 00:00:00'), 'Confirmed': 1512707},
#  {'Date': Timestamp('2022-03-04 00:00:00'), 'Confirmed': 1513503}]
